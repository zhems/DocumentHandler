# %%
from openpyxl import Workbook
from openpyxl import load_workbook #workbook.save(filename="new.xlsx")
import pandas as pd
workbook = load_workbook(filename="Monthly Report_Carpark_F1 - July 23.xlsx")
workbook.sheetnames
# Out:
# ['Data Format',
#  'Utilisation Rate Report',
#  'Report A-Daily Counter Trans',
#  'Report E- Termination of Season',
#  'Report F-Complimentay Ticket',
#  'Report G - Defects',
#  'Report H- Complaints received']

# %%
sheet = workbook.active
sheet
# Out:
# <Worksheet "Utilisation Rate Report">

# %%
sheet = workbook['Report A-Daily Counter Trans']

# %%
sheet.title
# Out:
# 'Report A-Daily Counter Trans'

# %%
sheet['B10'].value

# %%
floor = sheet.max_row

# %%
sheet[f'B10:B{floor}']
# Out:
# ((<Cell 'Report A-Daily Counter Trans'.B10>,),
#  (<Cell 'Report A-Daily Counter Trans'.B11>,),
#  (<Cell 'Report A-Daily Counter Trans'.B12>,),
#  (<Cell 'Report A-Daily Counter Trans'.B13>,),
#  (<Cell 'Report A-Daily Counter Trans'.B14>,),
#  (<Cell 'Report A-Daily Counter Trans'.B15>,),
#  (<Cell 'Report A-Daily Counter Trans'.B16>,),
#  (<Cell 'Report A-Daily Counter Trans'.B17>,),
#  (<Cell 'Report A-Daily Counter Trans'.B18>,),
#  (<Cell 'Report A-Daily Counter Trans'.B19>,),
#  (<Cell 'Report A-Daily Counter Trans'.B20>,),
#  (<Cell 'Report A-Daily Counter Trans'.B21>,),
#  (<Cell 'Report A-Daily Counter Trans'.B22>,),
#  (<Cell 'Report A-Daily Counter Trans'.B23>,),
#  (<Cell 'Report A-Daily Counter Trans'.B24>,),
#  (<Cell 'Report A-Daily Counter Trans'.B25>,),
#  (<Cell 'Report A-Daily Counter Trans'.B26>,),
#  (<Cell 'Report A-Daily Counter Trans'.B27>,),
#  (<Cell 'Report A-Daily Counter Trans'.B28>,),
#  (<Cell 'Report A-Daily Counter Trans'.B29>,),
# ...

# %%
sheet[f'B10:B{floor}'][0][0].value
# Out:
# '01/07/2023'

# %%
[i[0].value for i in sheet[f'B10:B{floor}']]
# Out:
# ['01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '01/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '02/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
#  '03/07/2023',
# ...
